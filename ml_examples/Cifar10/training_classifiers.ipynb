# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
(X_train, y_train), (X_valid, y_valid) = keras.datasets.cifar10.load_data()
X_train = np.float32(X_train / 255.0)
X_valid = np.float32(X_valid / 255.0)

# %%
model_1 = keras.models.Sequential()
model_1.add(keras.layers.Flatten(input_shape=[32,32,3]))
for i in range (10):
    model_1.add(keras.layers.Dense(100, activation='relu', kernel_initializer='he_normal'))
model_1.add(keras.layers.Dense(10, activation='softmax'))

model_1.compile(loss='sparse_categorical_crossentropy',
                optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
                metrics=['accuracy'])

history_1 = model_1.fit(X_train, y_train,
                        epochs=100,
                        validation_data=(X_valid, y_valid),
                        callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 15s 300us/sample - loss: 1.9734 - accuracy: 0.2667 - val_loss: 1.8449 - val_accuracy: 0.3349
# Epoch 2/100
# 50000/50000 [==============================] - 15s 308us/sample - loss: 1.8146 - accuracy: 0.3388 - val_loss: 1.7461 - val_accuracy: 0.3689
# Epoch 3/100
# 50000/50000 [==============================] - 15s 304us/sample - loss: 1.7533 - accuracy: 0.3647 - val_loss: 1.7061 - val_accuracy: 0.3878
# Epoch 4/100
# 50000/50000 [==============================] - 16s 316us/sample - loss: 1.7074 - accuracy: 0.3851 - val_loss: 1.6693 - val_accuracy: 0.3976
# Epoch 5/100
# 50000/50000 [==============================] - 16s 324us/sample - loss: 1.6749 - accuracy: 0.3947 - val_loss: 1.6858 - val_accuracy: 0.3893
# Epoch 6/100
# 50000/50000 [==============================] - 17s 332us/sample - loss: 1.6458 - accuracy: 0.4075 - val_loss: 1.6353 - val_accuracy: 0.4040
# Epoch 7/100
# 50000/50000 [==============================] - 16s 314us/sample - loss: 1.6144 - accuracy: 0.4195 - val_loss: 1.6212 - val_accuracy: 0.4109
# Epoch 8/100
# 50000/50000 [==============================] - 15s 301us/sample - loss: 1.5999 - accuracy: 0.4246 - val_loss: 1.6054 - val_accuracy: 0.4218
# Epoch 9/100
# 50000/50000 [==============================] - 16s 322us/sample - loss: 1.5795 - accuracy: 0.4297 - val_loss: 1.6171 - val_accuracy: 0.4210
# Epoch 10/100
# 50000/50000 [==============================] - 18s 352us/sample - loss: 1.5619 - accuracy: 0.4382 - val_loss: 1.5854 - val_accuracy: 0.4322
# Epoch 11/100
# 50000/50000 [==============================] - 18s 360us/sample - loss: 1.5454 - accuracy: 0.4433 - val_loss: 1.5442 - val_accuracy: 0.4518
# Epoch 12/100
# 50000/50000 [==============================] - 17s 340us/sample - loss: 1.5303 - accuracy: 0.4505 - val_loss: 1.5561 - val_accuracy: 0.4515
# Epoch 13/100
# 50000/50000 [==============================] - 16s 329us/sample - loss: 1.5253 - accuracy: 0.4501 - val_loss: 1.6085 - val_accuracy: 0.4224
# Epoch 14/100
# 50000/50000 [==============================] - 17s 342us/sample - loss: 1.5124 - accuracy: 0.4577 - val_loss: 1.5346 - val_accuracy: 0.4499
# Epoch 15/100
# 50000/50000 [==============================] - 17s 348us/sample - loss: 1.5046 - accuracy: 0.4579 - val_loss: 1.5472 - val_accuracy: 0.4489
# Epoch 16/100
# 50000/50000 [==============================] - 18s 364us/sample - loss: 1.4946 - accuracy: 0.4634 - val_loss: 1.5596 - val_accuracy: 0.4504
# Epoch 17/100
# 50000/50000 [==============================] - 18s 357us/sample - loss: 1.4907 - accuracy: 0.4662 - val_loss: 1.5406 - val_accuracy: 0.4518
# Epoch 18/100
# 50000/50000 [==============================] - 17s 349us/sample - loss: 1.4802 - accuracy: 0.4713 - val_loss: 1.5239 - val_accuracy: 0.4590
# Epoch 19/100
# 50000/50000 [==============================] - 16s 316us/sample - loss: 1.4687 - accuracy: 0.4747 - val_loss: 1.5859 - val_accuracy: 0.4380
# Epoch 20/100
# 50000/50000 [==============================] - 16s 327us/sample - loss: 1.4634 - accuracy: 0.4750 - val_loss: 1.5341 - val_accuracy: 0.4558
# Epoch 21/100
# 50000/50000 [==============================] - 17s 335us/sample - loss: 1.4555 - accuracy: 0.4771 - val_loss: 1.5447 - val_accuracy: 0.4564
# Epoch 22/100
# 50000/50000 [==============================] - 17s 335us/sample - loss: 1.4510 - accuracy: 0.4797 - val_loss: 1.5544 - val_accuracy: 0.4484
# Epoch 23/100
# 50000/50000 [==============================] - 16s 327us/sample - loss: 1.4467 - accuracy: 0.4824 - val_loss: 1.5364 - val_accuracy: 0.4515

# %%
model_2 = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model_2.compile(loss='sparse_categorical_crossentropy',
                optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
                metrics=['accuracy'])

history_2 = model_2.fit(X_train, y_train,
                        epochs=100,
                        validation_data=(X_valid, y_valid),
                        callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 464s 9ms/sample - loss: 1.7742 - accuracy: 0.3381 - val_loss: 1.4848 - val_accuracy: 0.4546
# Epoch 2/100
# 50000/50000 [==============================] - 465s 9ms/sample - loss: 1.3623 - accuracy: 0.5066 - val_loss: 1.2332 - val_accuracy: 0.5578
# Epoch 3/100
# 50000/50000 [==============================] - 456s 9ms/sample - loss: 1.1433 - accuracy: 0.5933 - val_loss: 1.1029 - val_accuracy: 0.6102
# Epoch 4/100
# 50000/50000 [==============================] - 451s 9ms/sample - loss: 0.9779 - accuracy: 0.6548 - val_loss: 1.0974 - val_accuracy: 0.6135
# Epoch 5/100
# 50000/50000 [==============================] - 440s 9ms/sample - loss: 0.8590 - accuracy: 0.6989 - val_loss: 0.9783 - val_accuracy: 0.6636
# Epoch 6/100
# 50000/50000 [==============================] - 441s 9ms/sample - loss: 0.7548 - accuracy: 0.7353 - val_loss: 0.9964 - val_accuracy: 0.6627
# Epoch 7/100
# 50000/50000 [==============================] - 441s 9ms/sample - loss: 0.6560 - accuracy: 0.7704 - val_loss: 0.9911 - val_accuracy: 0.6733
# Epoch 8/100
# 50000/50000 [==============================] - 444s 9ms/sample - loss: 0.5675 - accuracy: 0.8017 - val_loss: 1.0585 - val_accuracy: 0.6681
# Epoch 9/100
# 50000/50000 [==============================] - 439s 9ms/sample - loss: 0.4958 - accuracy: 0.8272 - val_loss: 1.1121 - val_accuracy: 0.6583
# Epoch 10/100
# 50000/50000 [==============================] - 437s 9ms/sample - loss: 0.4300 - accuracy: 0.8500 - val_loss: 1.1900 - val_accuracy: 0.6650

# %%
model_3 = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

model_3.compile(loss='sparse_categorical_crossentropy',
                optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
                metrics=['accuracy'])

history_3 = model_3.fit(X_train, y_train,
                        epochs=100,
                        validation_data=(X_valid, y_valid),
                        callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 437s 9ms/sample - loss: 2.3030 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 2/100
# 50000/50000 [==============================] - 437s 9ms/sample - loss: 2.3028 - accuracy: 0.0987 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 3/100
# 50000/50000 [==============================] - 435s 9ms/sample - loss: 2.3028 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/100
# 50000/50000 [==============================] - 433s 9ms/sample - loss: 2.3028 - accuracy: 0.1004 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 5/100
# 50000/50000 [==============================] - 433s 9ms/sample - loss: 2.3027 - accuracy: 0.1014 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/100
# 50000/50000 [==============================] - 432s 9ms/sample - loss: 2.3029 - accuracy: 0.0957 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/100
# 50000/50000 [==============================] - 433s 9ms/sample - loss: 2.3028 - accuracy: 0.0986 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/100
# 50000/50000 [==============================] - 433s 9ms/sample - loss: 2.3028 - accuracy: 0.0997 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 9/100
# 50000/50000 [==============================] - 435s 9ms/sample - loss: 2.3028 - accuracy: 0.0997 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/100
# 50000/50000 [==============================] - 435s 9ms/sample - loss: 2.3028 - accuracy: 0.0973 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 11/100
# 50000/50000 [==============================] - 436s 9ms/sample - loss: 2.3028 - accuracy: 0.0976 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 12/100
# 50000/50000 [==============================] - 437s 9ms/sample - loss: 2.3028 - accuracy: 0.0969 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 13/100
# 50000/50000 [==============================] - 437s 9ms/sample - loss: 2.3028 - accuracy: 0.0980 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 14/100
# 50000/50000 [==============================] - 439s 9ms/sample - loss: 2.3028 - accuracy: 0.1010 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 15/100
# 50000/50000 [==============================] - 438s 9ms/sample - loss: 2.3028 - accuracy: 0.0965 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 16/100
# 50000/50000 [==============================] - 438s 9ms/sample - loss: 2.3028 - accuracy: 0.0983 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 17/100
# 50000/50000 [==============================] - 438s 9ms/sample - loss: 2.3028 - accuracy: 0.0972 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 18/100
# 50000/50000 [==============================] - 439s 9ms/sample - loss: 2.3028 - accuracy: 0.0979 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 19/100
# 50000/50000 [==============================] - 438s 9ms/sample - loss: 2.3027 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 20/100
# 50000/50000 [==============================] - 439s 9ms/sample - loss: 2.3028 - accuracy: 0.0987 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 21/100
# 50000/50000 [==============================] - 438s 9ms/sample - loss: 2.3028 - accuracy: 0.0986 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 22/100
# 50000/50000 [==============================] - 439s 9ms/sample - loss: 2.3028 - accuracy: 0.0981 - val_loss: 2.3026 - val_accuracy: 0.1000

# %%
model_4 = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(10, activation='softmax')
])

model_4.compile(loss='sparse_categorical_crossentropy',
                optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
                metrics=['accuracy'])

history_4 = model_4.fit(X_train, y_train,
                        epochs=100,
                        validation_data=(X_valid, y_valid),
                        callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 471s 9ms/sample - loss: 1.7397 - accuracy: 0.3530 - val_loss: 1.4145 - val_accuracy: 0.4911
# Epoch 2/100
# 50000/50000 [==============================] - 467s 9ms/sample - loss: 1.3241 - accuracy: 0.5213 - val_loss: 1.1869 - val_accuracy: 0.5764
# Epoch 3/100
# 50000/50000 [==============================] - 473s 9ms/sample - loss: 1.1136 - accuracy: 0.6064 - val_loss: 1.0863 - val_accuracy: 0.6152
# Epoch 4/100
# 50000/50000 [==============================] - 472s 9ms/sample - loss: 0.9649 - accuracy: 0.6616 - val_loss: 1.0161 - val_accuracy: 0.6469
# Epoch 5/100
# 50000/50000 [==============================] - 466s 9ms/sample - loss: 0.8379 - accuracy: 0.7079 - val_loss: 0.9485 - val_accuracy: 0.6802
# Epoch 6/100
# 50000/50000 [==============================] - 473s 9ms/sample - loss: 0.7413 - accuracy: 0.7404 - val_loss: 0.9560 - val_accuracy: 0.6779
# Epoch 7/100
# 50000/50000 [==============================] - 466s 9ms/sample - loss: 0.6522 - accuracy: 0.7730 - val_loss: 0.9844 - val_accuracy: 0.6836
# Epoch 8/100
# 50000/50000 [==============================] - 466s 9ms/sample - loss: 0.5744 - accuracy: 0.7979 - val_loss: 0.9913 - val_accuracy: 0.6939
# Epoch 9/100
# 50000/50000 [==============================] - 476s 10ms/sample - loss: 0.5084 - accuracy: 0.8219 - val_loss: 1.0360 - val_accuracy: 0.6807
# Epoch 10/100
# 50000/50000 [==============================] - 473s 9ms/sample - loss: 0.4548 - accuracy: 0.8401 - val_loss: 1.0917 - val_accuracy: 0.6833

# %%
model_4.evaluate(X_valid, y_valid)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [1.091681706237793, 0.6833]
